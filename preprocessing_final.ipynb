# %%
import pandas as pd

def read_conll_file(file_path):
    sentences = []
    with open(file_path, encoding='utf-8') as f:
        current_sentence = []
        for line in f:
            line = line.strip()
            if not line:
                sentences.append(current_sentence)
                current_sentence = []
            elif not line.startswith('#'):
                fields = line.split('\t')
                current_sentence.append(fields)
    if current_sentence:
        sentences.append(current_sentence)
    return sentences

# %%
def write_conll_file(sentences, file_path):
    with open(file_path, 'w', encoding='utf-8') as f:
        for sentence in sentences:
            for fields in sentence:
                # Convert float values to strings
                f.write('\t'.join(fields) + '\n')
            f.write('\n')

# %%
def repeat_multi_predicate_sentences(sentences):
    final_sentences = []
    for sentence in sentences:
        # Check if sentence has at least 11 fields
        if len(sentence[0]) < 11:
            continue
        # Get the values of all predicate columns in the sentence
        predicate_values = list([fields[10] for fields in sentence if len(fields) >= 11])
        predicate_values = [item for item in predicate_values if item != '_']
        # If there is only one predicate value or no predicates, don't repeat the sentence
        if len(predicate_values) <= 1:
            final_sentences.append(sentence)
        elif len(predicate_values) > 1:
            # Repeat sentence for each predicate value
            for i, pred in enumerate(predicate_values):
                b = i + 1
                # Convert sentence to DataFrame
                df = pd.DataFrame(sentence)
                # Create a new DataFrame with only the first 11 columns of the original DataFrame
                df_2 = df.iloc[:, :11].copy()
                new_col = df.iloc[:, (10 + b)]
                df_2[11] = new_col

                new_sentence = df_2.values.tolist()
                final_sentences.append(new_sentence)
                
    return final_sentences

# %%
sentences = read_conll_file('../data/en_ewt-up-dev.conllu')

# %%
sentences = repeat_multi_predicate_sentences(sentences)

# %%
write_conll_file(sentences, 'output2.conllu')

# %%
df_dev = pd.read_csv('output2.conllu', sep = '\t', header = None, names = ["id", "word", "lemma", "posuniv", "pos", "morph","head", "dep", "head_dep" , "space", "predicate", "gold_label"])

# %%
df_dev[:40]
# Out:
#       id         word       lemma posuniv  pos  \
# 0    1.0         From        from     ADP   IN
# 1    2.0          the         the     DET   DT
# 2    3.0           AP          AP   PROPN  NNP
# 3    4.0        comes        come    VERB  VBZ
# 4    5.0         this        this     DET   DT
# 5    6.0        story       story    NOUN   NN
# 6    7.0            :           :   PUNCT    :
# 7    1.0    President   President   PROPN  NNP
# 8    2.0         Bush        Bush   PROPN  NNP
# 9    3.0           on          on     ADP   IN
# 10   4.0      Tuesday     Tuesday   PROPN  NNP
# 11   5.0    nominated    nominate    VERB  VBD
# 12   6.0          two         two     NUM   CD
# 13   7.0  individuals  individual    NOUN  NNS
# 14   8.0           to          to    PART   TO
# 15   9.0      replace     replace    VERB   VB
# 16  10.0     retiring      retire    VERB  VBG
# 17  11.0      jurists      jurist    NOUN  NNS
# 18  12.0           on          on     ADP   IN
# 19  13.0      federal     federal     ADJ   JJ
# 20  14.0       courts       court    NOUN  NNS
# 21  15.0           in          in     ADP   IN
# 22  16.0          the         the     DET   DT
# 23  17.0   Washington  Washington   PROPN  NNP
# 24  18.0         area        area    NOUN   NN
# 25  19.0            .           .   PUNCT    .
# 26   1.0    President   President   PROPN  NNP
# 27   2.0         Bush        Bush   PROPN  NNP
# 28   3.0           on          on     ADP   IN
# 29   4.0      Tuesday     Tuesday   PROPN  NNP
# 30   5.0    nominated    nominate    VERB  VBD
# 31   6.0          two         two     NUM   CD
# 32   7.0  individuals  individual    NOUN  NNS
# 33   8.0           to          to    PART   TO
# 34   9.0      replace     replace    VERB   VB
# 35  10.0     retiring      retire    VERB  VBG
# 36  11.0      jurists      jurist    NOUN  NNS
# 37  12.0           on          on     ADP   IN
# 38  13.0      federal     federal     ADJ   JJ
# 39  14.0       courts       court    NOUN  NNS
#
#                                                 morph head       dep  \
# 0                                                   _    3      case
# 1                           Definite=Def|PronType=Art    3       det
# 2                                         Number=Sing    4       obl
# 3   Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...    0      root
# 4                            Number=Sing|PronType=Dem    6       det
# 5                                         Number=Sing    4     nsubj
# 6                                                   _    4     punct
# 7                                         Number=Sing    5     nsubj
# 8                                         Number=Sing    1      flat
# 9                                                   _    4      case
# 10                                        Number=Sing    5       obl
# 11                   Mood=Ind|Tense=Past|VerbForm=Fin    0      root
# 12                                       NumType=Card    7    nummod
# 13                                        Number=Plur    5       obj
# 14                                                  _    9      mark
# 15                                       VerbForm=Inf    5     advcl
# 16                                       VerbForm=Ger   11      amod
# 17                                        Number=Plur    9       obj
# 18                                                  _   14      case
# 19                                         Degree=Pos   14      amod
# 20                                        Number=Plur   11      nmod
# 21                                                  _   18      case
# 22                          Definite=Def|PronType=Art   18       det
# 23                                        Number=Sing   18  compound
# 24                                        Number=Sing   14      nmod
# 25                                                  _    5     punct
# 26                                        Number=Sing    5     nsubj
# 27                                        Number=Sing    1      flat
# 28                                                  _    4      case
# 29                                        Number=Sing    5       obl
# 30                   Mood=Ind|Tense=Past|VerbForm=Fin    0      root
# 31                                       NumType=Card    7    nummod
# 32                                        Number=Plur    5       obj
# 33                                                  _    9      mark
# 34                                       VerbForm=Inf    5     advcl
# 35                                       VerbForm=Ger   11      amod
# 36                                        Number=Plur    9       obj
# 37                                                  _   14      case
# 38                                         Degree=Pos   14      amod
# 39                                        Number=Plur   11      nmod
#
#        head_dep          space    predicate gold_label
# 0        3:case              _            _          _
# 1         3:det              _            _          _
# 2    4:obl:from              _            _       ARG2
# 3        0:root              _      come.03          V
# 4         6:det              _            _          _
# 5       4:nsubj              _            _       ARG1
# 6       4:punct              _            _          _
# 7       5:nsubj              _            _       ARG0
# 8        1:flat              _            _          _
# 9        4:case              _            _          _
# 10     5:obl:on              _            _   ARGM-TMP
# 11       0:root              _  nominate.01          V
# 12     7:nummod              _            _          _
# 13        5:obj              _            _       ARG1
# 14       9:mark              _            _          _
# 15   5:advcl:to              _   replace.01       ARG2
# 16      11:amod              _            _          _
# 17        9:obj              _            _          _
# 18      14:case              _            _          _
# 19      14:amod              _            _          _
# 20   11:nmod:on              _            _          _
# 21      18:case              _            _          _
# 22       18:det              _            _          _
# 23  18:compound              _            _          _
# 24   14:nmod:in  SpaceAfter=No            _          _
# 25      5:punct              _            _          _
# 26      5:nsubj              _            _          _
# 27       1:flat              _            _          _
# 28       4:case              _            _          _
# 29     5:obl:on              _            _          _
# 30       0:root              _  nominate.01          _
# 31     7:nummod              _            _          _
# 32        5:obj              _            _       ARG0
# 33       9:mark              _            _          _
# 34   5:advcl:to              _   replace.01          V
# 35      11:amod              _            _          _
# 36        9:obj              _            _       ARG1
# 37      14:case              _            _          _
# 38      14:amod              _            _          _
# 39   11:nmod:on              _            _          _
